# %%
from bs4 import BeautifulSoup
import requests
page = requests.get("https://www.wunderground.com")
page
# Out:
# <Response [200]>

# %%
import requests
from pprint import pprint
def weather_data(query):
	res=requests.get('http://api.openweathermap.org/data/2.5/weather?'+query+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric');
	return res.json();
def print_weather(result,city):
	print("{}'s temperature: {}°C ".format(city,result['main']['temp']))
	print("Wind speed: {} m/s".format(result['wind']['speed']))
	print("Description: {}".format(result['weather'][0]['description']))
	print("Weather: {}".format(result['weather'][0]['main']))
def main():
	city=input('Enter the city:')
	print()
	try:
	  query='q='+city;
	  w_data=weather_data(query);
	  print_weather(w_data, city)
	  print()
	except:
	  print('City name not found...')
if __name__=='__main__':
	main()
# Out:
# Enter the city:malaysia
#
# malaysia's temperature: 31°C
# Wind speed: 2.1 m/s
# Description: broken clouds
# Weather: Clouds

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page = requests.get("https://www.worldweatheronline.com/petaling-jaya-weather/kuala-lumpur/my.aspx")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find_all('div', class_='weather_tb tb_day tb_days')
#print(seven_day)
forecast_items = seven_day[0].find(class_='tb_row tb_temp')
print(forecast_items.prettify())
#tonight = forecast_items[0]
#print(tonight.prettify())
# Out:
# <div class="tb_row tb_temp">
#  <div class="tb_cont_item">
#   <div class="flex_row">
#    <div class="tb_row_icon flex_coll">
#     <img alt="Temperature" src="//cdn.worldweatheronline.net/staticv150817/img/svg/temp.svg"/>
#    </div>
#    <div class="title flex_coll">
#     Temperature
#    </div>
#   </div>
#  </div>
#  <div class="tb_cont_item" style="background-color:#C4EE36;">
#   24 °c
#  </div>
#  <div class="tb_cont_item" style="background-color:#F1C151;">
#   31 °c
#  </div>
#  <div class="tb_cont_item" style="background-color:#F1C151;">
#   29 °c
#  </div>
#  <div class="tb_cont_item" style="background-color:#E9D97E;">
#   26 °c
#  </div>
# </div>

# %%
page = requests.get("https://www.worldweatheronline.com/petaling-jaya-weather/kuala-lumpur/my.aspx")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find_all('div', class_='tb_wrapper mobile_tb visible-xs')
#print(seven_day)
forecast_items = seven_day[0].find_all(class_="tb_content")
#print(forecast_items)
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tb_content">
#  <div class="tb_row tb_rain">
#   <div class="tb_cont_item">
#    <div class="flex_row">
#     <div class="tb_row_icon flex_coll">
#      <img alt="Rain" src="//cdn.worldweatheronline.net/staticv150817/img/svg/rain.svg"/>
#     </div>
#     <div class="title flex_coll">
#      Rain
#     </div>
#    </div>
#   </div>
#   <div class="tb_cont_item">
#    81%
#   </div>
#   <div class="tb_cont_item">
#    80%
#   </div>
#   <div class="tb_cont_item">
#    86%
#   </div>
#   <div class="tb_cont_item">
#    79%
#   </div>
#   <div class="tb_cont_item">
#    0%
#   </div>
#  </div>
#  <div class="tb_row tb_max">
#   <div class="tb_cont_item">
#    <div class="flex_row">
#     <div class="tb_row_icon flex_coll">
#      <img alt="High" src="//cdn.worldweatheronline.net/staticv150817/img/svg/temp.svg"/>
#     </div>
#     <div class="title flex_coll">
#      High
#     </div>
#    </div>
#   </div>
#   <div class="tb_cont_item" style="background-color:#F1C151;">
# ...

# %%
period = tonight.find(class_="title flex_coll").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()
print(period)
print(short_desc)
print(temp)
# Out:
# Rain
